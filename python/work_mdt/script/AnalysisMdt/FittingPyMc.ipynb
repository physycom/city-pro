# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import os
#gdf = gpd.read_file("/home/aamad/codice/city-pro/bologna-provincia.geojson")
fig, ax = plt.subplots(figsize=(10, 10))
# Convert CRS and plot the GeoDataFrame
gdf.to_crs(epsg=3857).plot(ax=ax, alpha=0.3, edgecolor='k')
# Add basemap
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
relative_path = "/home/aamad/codice/city-pro/output/bologna_mdt_detailed/BolognaMDTClassInfo.png"
fig.savefig(SaveFig,dpi = 200)
