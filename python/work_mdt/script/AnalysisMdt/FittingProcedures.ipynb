# %%
from FittingProcedures import *
import matplotlib.pyplot as plt
from scipy.special import gamma
from scipy.optimize import curve_fit,minimize
from scipy import stats
from scipy.stats import powerlaw as plw
import numpy as np

N = 1000
xmax = 100
x = np.linspace(1,100,N)
Noise = np.random.normal(0,10,N)
A = 1110
b = -2
initial_guess = [1100,-1]

for StrFunction,Function in Name2Function.items():
    if StrFunction is not 'vespignani' and StrFunction in Name2EstimateParameters.keys():
        y = Function(x,A,b) + Noise
        fit,StdError,ConvergenceSuccess = FitAndStdError(x,y,label = StrFunction,initial_guess = (6000,0.3),maxfev = 50000,interval = [])      
        fig, ax = plt.subplots()
        print("Function: ",StrFunction)
        print("Fit: ",fit)
        print("StdError: ",StdError)
        ax.plot(x, y, 'b-', label='data')
        ax.plot(x, Function(x, *fit[0]), 'r-', label='fit')
        ax.set_title(StrFunction)
#        ax.legend(loc='best')
        plt.show()
# Out:
# <>:18: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# <>:18: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /tmp/ipykernel_53777/2843498018.py:18: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   if StrFunction is not 'vespignani' and StrFunction in Name2EstimateParameters.keys():
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:80: RuntimeWarning: invalid value encountered in log
#   logy = np.log(y)
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:89: RuntimeWarning: divide by zero encountered in scalar divide
#   amp = index*logy[elem0_couple]/logx[elem0_couple]
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:16: RuntimeWarning: invalid value encountered in scalar multiply
#   return amp * (np.array(x)**index)
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:92: RuntimeWarning: invalid value encountered in log
#   index = (logy[elem1_couple] - np.log(amp))/logx[elem1_couple]
# Estimate Parameters:  0 0
# Message:  Desired error not necessarily achieved due to precision loss.
# Function:  powerlaw
# Fit:  (array([1103.75521434,   -1.97657443]), array([[ 4.24242176e+01, -5.63629059e-02],
#        [-5.63629059e-02,  1.75543132e-04]]))
# StdError:  9.792264617115698
# Estimate Parameters:  1110.0 -2.0
# Message:  Desired error not necessarily achieved due to precision loss.
# Function:  exponential
# Fit:  (array([1110.,   -2.]), array([[1.46327304e-168, 1.32094878e-173],
#        [1.32094878e-173, 1.19247497e-178]]))
# StdError:  3.798930736145061
# /home/aamad/miniconda3/envs/geostuff/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   alpha1 = min(1.0, 1.01*2*(phi0 - old_phi0)/derphi0)
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:20: RuntimeWarning: overflow encountered in exp
#   return amp * np.exp(-index*np.array(x))
# /home/aamad/miniconda3/envs/geostuff/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /home/aamad/miniconda3/envs/geostuff/lib/python3.12/site-packages/scipy/optimize/_linesearch.py:396: RuntimeWarning: invalid value encountered in scalar divide
#   alpha1 = min(1.0, 1.01*2*(phi0 - old_phi0)/derphi0)
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:20: RuntimeWarning: overflow encountered in exp
#   return amp * np.exp(-index*np.array(x))
# Estimate Parameters:  1099.2785994258177 527.1630872017843
# Message:  Desired error not necessarily achieved due to precision loss.
# Function:  linear
# Fit:  (array([1109.99702254,   -1.50093457]), array([[ 1.17614884e-04, -5.93945685e-03],
#        [-5.93945685e-03,  3.96184758e-01]]))
# StdError:  9.80094753742449
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:179: RuntimeWarning: invalid value encountered in log
#   sigma = np.sqrt(-2*np.log(y[elem0_couple]/(mu/sigma)**2))
# Estimate Parameters:  0 0
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:56: RuntimeWarning: divide by zero encountered in divide
#   return (x/sigma)**2 * np.exp(-(x - mu)**2 / (2 * sigma**2))
# /home/aamad/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:56: RuntimeWarning: invalid value encountered in multiply
#   return (x/sigma)**2 * np.exp(-(x - mu)**2 / (2 * sigma**2))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 20
#      18 if StrFunction is not 'vespignani' and StrFunction in Name2EstimateParameters.keys():
#      19     y = Function(x,A,b) + Noise
# ---> 20     fit,StdError,ConvergenceSuccess = FitAndStdError(x,y,label = StrFunction,initial_guess = (6000,0.3),maxfev = 50000,interval = [])
#      21     fig, ax = plt.subplots()
#      22     print("Function: ",StrFunction)
#
# File ~/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:389, in FitAndStdError(x, y_measured, label, initial_guess, maxfev, interval)
#     388 def FitAndStdError(x,y_measured,label,initial_guess,maxfev = 50000,interval = []):
# --> 389     fit,ConvergenceSuccess = Fitting(x,y_measured,label,initial_guess = initial_guess,maxfev = maxfev,interval = interval)
#     390     if len(fit[0]) == 2:
#     391         A = fit[0][0]
#
# File ~/codice/city-pro/python/work_mdt/script/AnalysisMdt/FittingProcedures.py:378, in Fitting(x, y_measured, label, initial_guess, maxfev, interval)
#     376     result_powerlaw = minimize(Name2LossFunction[label], initial_guess, args = (x, y_measured))#,maxfev = maxfev
#     377     optimal_params_plw = result_powerlaw.x
# --> 378     fit = curve_fit(Name2Function[label], xdata = x, ydata = y_measured,p0 = list(optimal_params_plw),maxfev = maxfev)
#     379 #    print(fit)
#     380 #    print('{} fit: '.format(label),fit[0][0],' ',fit[0][1])
#     381 #    print('Convergence fit {}: '.format(label),result_powerlaw.success)
#     382 #    print('Optimal parameters: ',result_powerlaw.x)
#     383     print('Message: ',result_powerlaw.message)
#
# File ~/miniconda3/envs/geostuff/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:1005, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1003     cost = np.sum(infodict['fvec'] ** 2)
#    1004     if ier not in [1, 2, 3, 4]:
# -> 1005         raise RuntimeError("Optimal parameters not found: " + errmsg)
#    1006 else:
#    1007     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#    1008     if 'max_nfev' not in kwargs:
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 50000.

# %%
import geopandas as gpd
gpd.read_file("/home/aamad/codice/city-pro/output/bologna_mdt_detailed/BolognaMDTClassInfo.geojson")
# Out:
#        poly_lid  poly_cid    poly_length    poly_nF  poly_nT  \
# 0         32536         0  3.952525e-322  168606153    32536
# 1             1   1000007   4.057440e+02        853       13
# 2             2   1000012   3.921655e+01         16    10944
# 3             3   1000014   4.473194e+01      10944     9618
# 4             4   1000016   1.681578e+01         27    81467
# ...         ...       ...            ...        ...      ...
# 18982     18982   1083563   1.068172e+02      16428    16427
# 18983     18983   1083564   6.924561e+01      16427    16429
# 18984     18984   1083565   3.382767e+02      16430    16431
# 18985     18985   1083567   1.419841e+03      16432    67475
# 18986     18986   1083571   1.441400e+03      14801    16434
#
#        IntClassOrdered_2022-12-30 StrClassOrdered_2022-12-30  \
# 0                               0                  1 slowest
# 1                               2      middle velocity class
# 2                               1                  2 slowest
# 3                               1                  2 slowest
# 4                               1                  2 slowest
# ...                           ...                        ...
# 18982                           0                  1 slowest
# 18983                           0                  1 slowest
# 18984                           0                  1 slowest
# 18985                           0                  1 slowest
# 18986                           0                  1 slowest
#
#        IntClass_2022-12-30  IntClassOrdered_2022-07-01  \
# 0                        0                           0
# 1                        2                           1
# 2                        1                           1
# 3                        1                           1
# 4                        1                           1
# ...                    ...                         ...
# 18982                    0                           0
# 18983                    0                           0
# 18984                    0                           0
# 18985                    0                           0
# 18986                    0                           0
#
#       StrClassOrdered_2022-07-01  ...  IntClassOrdered_2022-12-31  \
# 0                      1 slowest  ...                           0
# 1                      2 slowest  ...                           2
# 2                      2 slowest  ...                           2
# 3                      2 slowest  ...                           2
# 4                      2 slowest  ...                           2
# ...                          ...  ...                         ...
# 18982                  1 slowest  ...                           0
# 18983                  1 slowest  ...                           0
# 18984                  1 slowest  ...                           0
# 18985                  1 slowest  ...                           0
# 18986                  1 slowest  ...                           0
#
#        StrClassOrdered_2022-12-31 IntClass_2022-12-31  \
# 0                       1 slowest                   0
# 1           middle velocity class                   2
# 2           middle velocity class                   2
# 3           middle velocity class                   2
# 4           middle velocity class                   2
# ...                           ...                 ...
# 18982                   1 slowest                   0
# 18983                   1 slowest                   0
# 18984                   1 slowest                   0
# 18985                   1 slowest                   0
# 18986                   1 slowest                   0
#
#        IntClassOrdered_2022-11-11  StrClassOrdered_2022-11-11  \
# 0                               0                   1 slowest
# 1                               1                   2 slowest
# 2                               1                   2 slowest
# 3                               1                   2 slowest
# 4                               1                   2 slowest
# ...                           ...                         ...
# 18982                           0                   1 slowest
# 18983                           0                   1 slowest
# 18984                           0                   1 slowest
# 18985                           0                   1 slowest
# 18986                           0                   1 slowest
#
#       IntClass_2022-11-11  IntClassOrdered_2022-08-05  \
# 0                       0                           0
# 1                       1                           3
# 2                       1                           1
# 3                       1                           1
# 4                       1                           1
# ...                   ...                         ...
# 18982                   0                           0
# 18983                   0                           0
# 18984                   0                           0
# 18985                   0                           0
# 18986                   0                           0
#
#        StrClassOrdered_2022-08-05 IntClass_2022-08-05  \
# 0                       1 slowest                   0
# 1                      1 quickest                   3
# 2                       2 slowest                   1
# 3                       2 slowest                   1
# 4                       2 slowest                   1
# ...                           ...                 ...
# 18982                   1 slowest                   0
# 18983                   1 slowest                   0
# 18984                   1 slowest                   0
# 18985                   1 slowest                   0
# 18986                   1 slowest                   0
#
#                                                 geometry
# 0                                                   None
# 1      LINESTRING (11.26144 44.48221, 11.26077 44.483...
# 2      LINESTRING (11.69918 44.35028, 11.69906 44.350...
# 3      LINESTRING (11.69889 44.35000, 11.69871 44.349...
# 4      LINESTRING (11.49278 44.43858, 11.49282 44.438...
# ...                                                  ...
# 18982  LINESTRING (10.84213 44.59478, 10.84341 44.59449)
# 18983  LINESTRING (10.84341 44.59449, 10.84424 44.59430)
# 18984  LINESTRING (10.84564 44.60201, 10.84477 44.599...
# 18985  LINESTRING (10.84772 44.60249, 10.83836 44.604...
# 18986  LINESTRING (10.83165 44.60894, 10.83030 44.609...
#
# [18987 rows x 30 columns]
