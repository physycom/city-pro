# %%
import pandas as pd
NewFcm = pd.read_csv('/home/aamad/Desktop/phd/codice/city-pro/output/bologna_mdt_detailed/bologna_mdt_2022-05-12_2022-05-12_fcm_new.csv',delimiter = ';')
Fcm = pd.read_csv('/home/aamad/Desktop/phd/codice/city-pro/output/bologna_mdt_detailed/bologna_mdt_2022-05-12_2022-05-12_fcm.csv',delimiter = ';')

# %%
import matplotlib.pyplot as plt
def PlotHisto(Fcm,column):
    fig,ax = plt.subplots(1,1,figsize=(10, 10))
    ax.hist(Fcm[column],label=column)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    plt.show()
PlotHisto(Fcm,'class')
PlotHisto(Fcm,'p')
